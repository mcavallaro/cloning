# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import cloning as cl
import numpy as np
from multiprocessing import Pool
pool = Pool(processes=4)

# %%
S = np.arange(-2, 2, 0.1)
SCGF = pool.map(cl.main, S)

# %%
plt.plot(S, SCGF)
plt.xlabel(r"$s$")
plt.xlabel(r""$e(s)$")
